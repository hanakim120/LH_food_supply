# %%
data = pd.read_csv('data.csv', encoding='utf-8')
target = pd.read_csv('target.csv', encoding='utf-8')

# %%
# model = sm.OLS(target.석식계, data.drop(columns=['요일점심평균', '월점심평균']))
model = sm.OLS(target.석식계, data, hasconst=True)

# %%
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    석식계   R-squared:                       0.404
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     34.80
# Date:                Tue, 13 Jul 2021   Prob (F-statistic):          1.74e-115
# Time:                        21:52:23   Log-Likelihood:                -7345.1
# No. Observations:                1205   AIC:                         1.474e+04
# Df Residuals:                    1181   BIC:                         1.486e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 공휴일전후        -102.4146     26.220     -3.906      0.000    -153.858     -50.971
# 공휴일길이        -168.0915     70.429     -2.387      0.017    -306.271     -29.912
# 휴가비율          191.3234     38.918      4.916      0.000     114.966     267.680
# 출장비율          350.9399     14.380     24.405      0.000     322.727     379.153
# 야근비율          349.3611     28.723     12.163      0.000     293.007     405.716
# 재택비율           95.2876     22.635      4.210      0.000      50.879     139.696
# year         -117.4142     13.861     -8.471      0.000    -144.608     -90.220
# week          -13.8226      2.557     -5.406      0.000     -18.839      -8.806
# 강수량            37.9743     34.544      1.099      0.272     -29.800     105.748
# 불쾌지수           92.6117     16.019      5.782      0.000      61.184     124.040
# 요일점심평균         93.3856     12.365      7.552      0.000      69.125     117.646
# 요일저녁평균         19.8318     17.764      1.116      0.264     -15.021      54.684
# 월점심평균         157.9830     19.491      8.106      0.000     119.743     196.223
# 월저녁평균          25.9168     19.998      1.296      0.195     -13.318      65.152
# 전일대비증감        115.0061     47.555      2.418      0.016      21.704     208.308
# breakfast_0    -4.6332      2.820     -1.643      0.101     -10.167       0.900
# breakfast_1    -5.1604      4.106     -1.257      0.209     -13.215       2.895
# breakfast_2     0.4249      4.619      0.092      0.927      -8.637       9.487
# lunch_0         0.1125      2.463      0.046      0.964      -4.720       4.945
# lunch_1        -3.4663      3.846     -0.901      0.368     -11.012       4.079
# lunch_2         0.0641      4.056      0.016      0.987      -7.894       8.022
# dinner_0       -2.7186      2.394     -1.136      0.256      -7.416       1.979
# dinner_1       -2.3646      3.353     -0.705      0.481      -8.942       4.213
# dinner_2       -4.6492      4.062     -1.145      0.253     -12.619       3.320
# ==============================================================================
# Omnibus:                      230.245   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              796.755
# Skew:                          -0.909   Prob(JB):                    9.70e-174
# Kurtosis:                       6.545   Cond. No.                         58.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.predict

# %%
# model = sm.OLS(target.석식계, data.drop(columns=['요일점심평균', '월점심평균']))
model = sm.OLS(target.중식계, data.drop(columns=['공휴일길이',
                                              'lunch_0', 'lunch_1', 'lunch_2',
                                              'dinner_0', 'dinner_1', 'dinner_2',
                                             ]), hasconst=True)

# %%
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    중식계   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     112.7
# Date:                Tue, 13 Jul 2021   Prob (F-statistic):          8.67e-225
# Time:                        21:47:52   Log-Likelihood:                -7593.3
# No. Observations:                1205   AIC:                         1.522e+04
# Df Residuals:                    1188   BIC:                         1.531e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# 공휴일전후        -142.7963     29.757     -4.799      0.000    -201.179     -84.413
# 휴가비율          264.2288     47.636      5.547      0.000     170.768     357.689
# 출장비율          591.1595     17.558     33.669      0.000     556.712     625.607
# 야근비율          358.1354     35.106     10.202      0.000     289.258     427.012
# 재택비율          237.1830     27.660      8.575      0.000     182.915     291.451
# year         -125.3424     16.945     -7.397      0.000    -158.587     -92.098
# week           -7.3707      3.124     -2.360      0.018     -13.499      -1.242
# 강수량           187.0999     42.132      4.441      0.000     104.438     269.762
# 불쾌지수          136.7576     19.595      6.979      0.000      98.312     175.203
# 요일점심평균        653.1743     15.129     43.175      0.000     623.493     682.856
# 요일저녁평균       -146.9920     21.715     -6.769      0.000    -189.596    -104.389
# 월점심평균         386.0272     23.806     16.216      0.000     339.321     432.733
# 월저녁평균        -110.1370     24.459     -4.503      0.000    -158.126     -62.148
# 전일대비증감        385.2170     58.025      6.639      0.000     271.374     499.060
# breakfast_0    -9.8303      3.409     -2.884      0.004     -16.518      -3.143
# breakfast_1    -3.9627      4.884     -0.811      0.417     -13.546       5.620
# breakfast_2    -8.1293      5.618     -1.447      0.148     -19.151       2.892
# ==============================================================================
# Omnibus:                       84.518   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              227.588
# Skew:                           0.364   Prob(JB):                     3.80e-50
# Kurtosis:                       5.001   Cond. No.                         41.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
