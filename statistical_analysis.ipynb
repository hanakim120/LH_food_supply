# %%
data = sm.add_constant(pd.read_csv('data.csv', encoding='utf-8'))
target = pd.read_csv('target.csv', encoding='utf-8')

# %%
# model = sm.OLS(target.석식계, data.drop(columns=['요일점심평균', '월점심평균']))
model = sm.OLS(target.석식계, data.drop(columns=['요일점심평균', '월점심평균', '요일저녁평균', '전일대비증감', 'lunch_0', 'lunch_1']))

# %%
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    석식계   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     112.9
# Date:                Tue, 13 Jul 2021   Prob (F-statistic):          9.88e-242
# Time:                        23:17:15   Log-Likelihood:                -7055.6
# No. Observations:                1205   AIC:                         1.415e+04
# Df Residuals:                    1186   BIC:                         1.425e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         527.0732     19.804     26.614      0.000     488.218     565.928
# ...

# %%
# model = sm.OLS(target.석식계, data.drop(columns=['요일점심평균', '월점심평균']))
model = sm.OLS(target.중식계, data.drop(columns=['월저녁평균', '요일저녁평균', '재택비율', 'breakfast_2', 'lunch_0', 'lunch_1', '공휴일길이']))

# %%
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    중식계   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     270.8
# Date:                Tue, 13 Jul 2021   Prob (F-statistic):               0.00
# Time:                        23:16:22   Log-Likelihood:                -7194.9
# No. Observations:                1205   AIC:                         1.443e+04
# Df Residuals:                    1187   BIC:                         1.452e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1038.8699     28.320     36.683      0.000     983.307    1094.433
# ...
